# %%
import torch
import torchvision
from torch import nn 
from torch.utils.tensorboard import SummaryWriter
from torchvision import transforms
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import Image 
#%matplotlib inline
import numpy as np

# %% [markdown]
# # Import and split dataset

# %%
df = pd.read_csv('final_dataset.csv',index_col=0)
tform = transforms.Compose([transforms.Resize((64,64)),transforms.PILToTensor(),transforms.ConvertImageDtype(torch.float),transforms.Normalize(0.5,0.5)])
image_dataset = torchvision.datasets.ImageFolder("image_dataset/",transform=tform)

figure = plt.figure(figsize=(8, 8))
cols, rows = 3, 3
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(image_dataset), size=(1,)).item()
    img, label = image_dataset[sample_idx]
    img = transforms.functional.to_pil_image(img)
    figure.add_subplot(rows, cols, i)
    species_name = (list(image_dataset.class_to_idx.keys())[label]).replace('_',' ')
    plt.title(species_name)
    plt.axis("off")
    plt.imshow(img, cmap="gray")
plt.show()

# %%
import random
import sys
import os

import dataset_utils
img2dna = dataset_utils.get_imgs_bold_id(image_dataset,df)

nucleotides = df[['nucleotide','species_name','genus_name','processid','image_urls']]
colonna_dna = df.loc[:,"nucleotide"]
nucleotides.loc[:,'nucleotide'] = colonna_dna.apply(dataset_utils.one_hot_encoding)
random.seed(42)

X_train_val, X_test, y_train_val, y_test = dataset_utils.data_split(nucleotides,0.2,random_state=42)
print(y_test)
train_data = X_train_val
train_data['species_name'] = y_train_val

X_train, X_validation, y_train, y_validation = dataset_utils.data_split(train_data,0.2,drop_labels=False,random_state=42)
train_indices, val_indices, test_indices = dataset_utils.image_splits_from_df(X_train,X_validation,X_test,image_dataset)
from torch.utils.data import Dataset, DataLoader
 
class WholeDataset(Dataset):
    def __init__(self, data, transform=None):
        self.data = data
        self.targets = data.targets#torch.tensor(targets)
        #self.transform = transform
        
    def __getitem__(self, index):
        x = self.data[index][0]
        y = self.targets[index]
        
        return x, y
    
    def __len__(self):
        return len(self.data)
        
whole_dataset = WholeDataset(image_dataset)
n_classes = np.unique(whole_dataset.targets).shape[0]
print(len(test_indices+val_indices+train_indices))
len(whole_dataset)
# Out:
# 365    Bembidion normannum
# 292       Bledius gallicus
# 321       Praxis edwardsii
# 352        Andrena pilipes
# 18     Automeris managuana
#               ...
# 412         Hemiceras losa
# 413         Hemiceras losa
# 417     Hemiceras punctata
# 418         Hemiceras losa
# 421     Hemiceras punctata
# Name: species_name, Length: 9991, dtype: object
# 32424
# 32424

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
latent_size = 100 
batch_size =  64

# %%
train_imgs = torch.utils.data.Subset(whole_dataset, train_indices)
val_imgs = torch.utils.data.Subset(whole_dataset, val_indices)
test_imgs = torch.utils.data.Subset(whole_dataset, test_indices)
len(train_imgs)+len(val_imgs)+len(test_imgs)
train_loader = torch.utils.data.DataLoader(train_imgs, batch_size=batch_size,shuffle=True, num_workers=2)
val_loader = torch.utils.data.DataLoader(val_imgs, batch_size=batch_size,shuffle=True, num_workers=2)
test_loader = torch.utils.data.DataLoader(test_imgs, batch_size=4,shuffle=True, num_workers=2)
del test_loader
dataloaders = {"train":train_loader,"val":val_loader}
dataset_sizes = {'train': len(train_imgs.indices), 'val':len(val_imgs.indices)}

print(len(train_imgs.indices))
print(len(val_imgs.indices))
print(len(test_imgs.indices))
# Out:
# 13039
# 6955
# 12430

# %%
print(y_test.shape)
print(y_train.shape)
# Out:
# (9991,)
# (10840,)

# %%
# USED TO GENERATE ONLY FAKE IMAGES FROM DESCRIBED SPECIES
described_species_labels = np.array([image_dataset.targets[i] for i in train_indices])
described_species_labels = np.unique(described_species_labels)

# %%
described_species_labels
# Out:
# array([   0,    1,    2,    3,    4,    5,    6,    7,    9,   12,   13,
#          15,   16,   18,   19,   21,   22,   23,   26,   29,   30,   32,
#          33,   37,   39,   40,   42,   43,   45,   46,   47,   49,   50,
#          51,   52,   53,   54,   56,   57,   60,   63,   64,   69,   70,
#          73,   74,   75,   76,   77,   78,   79,   80,   82,   83,   84,
#          85,   86,   88,   91,   95,   96,   97,   98,  100,  101,  102,
#         103,  106,  108,  110,  111,  113,  116,  117,  118,  119,  120,
#         121,  122,  123,  124,  126,  127,  131,  132,  134,  135,  136,
#         138,  139,  140,  141,  142,  143,  145,  147,  148,  149,  151,
#         153,  154,  156,  158,  159,  160,  163,  164,  165,  167,  168,
#         170,  171,  172,  173,  174,  177,  178,  180,  181,  182,  184,
#         185,  191,  194,  195,  196,  199,  202,  203,  204,  205,  206,
#         207,  208,  209,  210,  211,  212,  213,  214,  215,  216,  217,
#         219,  220,  221,  222,  223,  224,  225,  227,  228,  231,  234,
#         236,  238,  240,  241,  243,  245,  246,  249,  250,  251,  252,
#         254,  256,  257,  258,  259,  260,  261,  263,  264,  265,  266,
#         267,  268,  270,  271,  274,  276,  278,  279,  281,  283,  285,
#         287,  291,  292,  293,  295,  296,  298,  299,  300,  301,  302,
#         303,  304,  305,  306,  307,  308,  311,  313,  315,  317,  318,
#         319,  320,  321,  322,  323,  324,  325,  326,  328,  329,  330,
#         334,  337,  338,  340,  342,  345,  346,  347,  348,  349,  353,
#         354,  358,  359,  360,  361,  362,  364,  365,  366,  367,  369,
#         370,  371,  372,  373,  375,  376,  377,  378,  380,  381,  382,
#         383,  384,  385,  387,  390,  391,  392,  393,  394,  397,  400,
#         401,  403,  404,  406,  407,  409,  411,  412,  413,  414,  417,
#         418,  419,  421,  423,  425,  426,  427,  429,  431,  432,  433,
#         434,  436,  437,  439,  440,  441,  442,  443,  444,  446,  449,
#         451,  453,  455,  457,  458,  459,  461,  466,  468,  469,  471,
#         472,  475,  476,  478,  479,  482,  483,  484,  485,  489,  490,
#         493,  495,  496,  497,  498,  499,  500,  502,  503,  505,  508,
#         511,  512,  513,  514,  515,  516,  518,  519,  520,  522,  523,
#         525,  526,  527,  528,  530,  533,  535,  537,  538,  539,  540,
#         541,  542,  543,  547,  549,  550,  552,  558,  559,  560,  561,
#         562,  563,  564,  566,  569,  574,  575,  576,  577,  578,  579,
#         580,  581,  584,  585,  587,  588,  589,  590,  591,  592,  593,
#         594,  595,  596,  597,  598,  604,  605,  607,  608,  609,  610,
#         611,  613,  614,  616,  617,  618,  619,  621,  622,  623,  624,
#         625,  627,  628,  632,  635,  636,  637,  638,  640,  641,  643,
#         645,  646,  648,  650,  651,  652,  653,  654,  655,  656,  657,
#         658,  659,  660,  661,  663,  666,  668,  670,  672,  674,  675,
#         676,  677,  680,  681,  682,  683,  684,  685,  686,  690,  691,
#         692,  693,  695,  696,  697,  698,  699,  700,  701,  702,  705,
#         706,  708,  709,  710,  711,  712,  713,  714,  715,  716,  717,
#         718,  719,  721,  723,  724,  725,  726,  729,  730,  731,  732,
#         734,  736,  737,  741,  742,  743,  745,  746,  748,  751,  752,
#         753,  754,  755,  758,  759,  760,  762,  764,  765,  766,  767,
#         768,  770,  772,  773,  774,  775,  777,  778,  779,  780,  783,
#         784,  785,  786,  787,  789,  791,  792,  793,  795,  797,  798,
#         799,  800,  801,  802,  805,  806,  807,  808,  809,  810,  811,
#         813,  814,  816,  818,  819,  821,  823,  824,  825,  826,  827,
#         828,  831,  834,  835,  836,  838,  839,  840,  843,  844,  847,
#         848,  849,  850,  852,  853,  854,  856,  857,  859,  860,  861,
#         862,  863,  864,  867,  869,  870,  871,  872,  873,  874,  875,
#         876,  877,  878,  881,  882,  885,  886,  888,  889,  891,  892,
#         893,  894,  895,  896,  897,  900,  901,  902,  904,  905,  906,
#         907,  908,  909,  910,  911,  912,  913,  914,  916,  917,  918,
#         919,  920,  921,  923,  925,  926,  927,  928,  929,  931,  932,
#         935,  937,  938,  939,  940,  942,  943,  944,  946,  948,  950,
#         951,  952,  954,  955,  957,  958,  959,  960,  961,  962,  963,
#         964,  965,  966,  967,  968,  970,  971,  972,  973,  975,  976,
#         977,  980,  983,  985,  986,  989,  991,  992,  995,  998,  999,
#        1000, 1003, 1004, 1006, 1007, 1008, 1012, 1013, 1016, 1017, 1018,
#        1019, 1020, 1021, 1022, 1025, 1027, 1028, 1030, 1031, 1032, 1033,
#        1034, 1038, 1039, 1040, 1041, 1042, 1045, 1047, 1048, 1049])

# %%
list(image_dataset.class_to_idx.keys())[45]
# Out:
# 'Agrotis_ipsilon'

# %%
described_species_labels
# Out:
# array([   0,    1,    2,    3,    4,    5,    6,    7,    9,   12,   13,
#          15,   16,   18,   19,   21,   22,   23,   26,   29,   30,   32,
#          33,   37,   39,   40,   42,   43,   45,   46,   47,   49,   50,
#          51,   52,   53,   54,   56,   57,   60,   63,   64,   69,   70,
#          73,   74,   75,   76,   77,   78,   79,   80,   82,   83,   84,
#          85,   86,   88,   91,   95,   96,   97,   98,  100,  101,  102,
#         103,  106,  108,  110,  111,  113,  116,  117,  118,  119,  120,
#         121,  122,  123,  124,  126,  127,  131,  132,  134,  135,  136,
#         138,  139,  140,  141,  142,  143,  145,  147,  148,  149,  151,
#         153,  154,  156,  158,  159,  160,  163,  164,  165,  167,  168,
#         170,  171,  172,  173,  174,  177,  178,  180,  181,  182,  184,
#         185,  191,  194,  195,  196,  199,  202,  203,  204,  205,  206,
#         207,  208,  209,  210,  211,  212,  213,  214,  215,  216,  217,
#         219,  220,  221,  222,  223,  224,  225,  227,  228,  231,  234,
#         236,  238,  240,  241,  243,  245,  246,  249,  250,  251,  252,
#         254,  256,  257,  258,  259,  260,  261,  263,  264,  265,  266,
#         267,  268,  270,  271,  274,  276,  278,  279,  281,  283,  285,
#         287,  291,  292,  293,  295,  296,  298,  299,  300,  301,  302,
#         303,  304,  305,  306,  307,  308,  311,  313,  315,  317,  318,
#         319,  320,  321,  322,  323,  324,  325,  326,  328,  329,  330,
#         334,  337,  338,  340,  342,  345,  346,  347,  348,  349,  353,
#         354,  358,  359,  360,  361,  362,  364,  365,  366,  367,  369,
#         370,  371,  372,  373,  375,  376,  377,  378,  380,  381,  382,
#         383,  384,  385,  387,  390,  391,  392,  393,  394,  397,  400,
#         401,  403,  404,  406,  407,  409,  411,  412,  413,  414,  417,
#         418,  419,  421,  423,  425,  426,  427,  429,  431,  432,  433,
#         434,  436,  437,  439,  440,  441,  442,  443,  444,  446,  449,
#         451,  453,  455,  457,  458,  459,  461,  466,  468,  469,  471,
#         472,  475,  476,  478,  479,  482,  483,  484,  485,  489,  490,
#         493,  495,  496,  497,  498,  499,  500,  502,  503,  505,  508,
#         511,  512,  513,  514,  515,  516,  518,  519,  520,  522,  523,
#         525,  526,  527,  528,  530,  533,  535,  537,  538,  539,  540,
#         541,  542,  543,  547,  549,  550,  552,  558,  559,  560,  561,
#         562,  563,  564,  566,  569,  574,  575,  576,  577,  578,  579,
#         580,  581,  584,  585,  587,  588,  589,  590,  591,  592,  593,
#         594,  595,  596,  597,  598,  604,  605,  607,  608,  609,  610,
#         611,  613,  614,  616,  617,  618,  619,  621,  622,  623,  624,
#         625,  627,  628,  632,  635,  636,  637,  638,  640,  641,  643,
#         645,  646,  648,  650,  651,  652,  653,  654,  655,  656,  657,
#         658,  659,  660,  661,  663,  666,  668,  670,  672,  674,  675,
#         676,  677,  680,  681,  682,  683,  684,  685,  686,  690,  691,
#         692,  693,  695,  696,  697,  698,  699,  700,  701,  702,  705,
#         706,  708,  709,  710,  711,  712,  713,  714,  715,  716,  717,
#         718,  719,  721,  723,  724,  725,  726,  729,  730,  731,  732,
#         734,  736,  737,  741,  742,  743,  745,  746,  748,  751,  752,
#         753,  754,  755,  758,  759,  760,  762,  764,  765,  766,  767,
#         768,  770,  772,  773,  774,  775,  777,  778,  779,  780,  783,
#         784,  785,  786,  787,  789,  791,  792,  793,  795,  797,  798,
#         799,  800,  801,  802,  805,  806,  807,  808,  809,  810,  811,
#         813,  814,  816,  818,  819,  821,  823,  824,  825,  826,  827,
#         828,  831,  834,  835,  836,  838,  839,  840,  843,  844,  847,
#         848,  849,  850,  852,  853,  854,  856,  857,  859,  860,  861,
#         862,  863,  864,  867,  869,  870,  871,  872,  873,  874,  875,
#         876,  877,  878,  881,  882,  885,  886,  888,  889,  891,  892,
#         893,  894,  895,  896,  897,  900,  901,  902,  904,  905,  906,
#         907,  908,  909,  910,  911,  912,  913,  914,  916,  917,  918,
#         919,  920,  921,  923,  925,  926,  927,  928,  929,  931,  932,
#         935,  937,  938,  939,  940,  942,  943,  944,  946,  948,  950,
#         951,  952,  954,  955,  957,  958,  959,  960,  961,  962,  963,
#         964,  965,  966,  967,  968,  970,  971,  972,  973,  975,  976,
#         977,  980,  983,  985,  986,  989,  991,  992,  995,  998,  999,
#        1000, 1003, 1004, 1006, 1007, 1008, 1012, 1013, 1016, 1017, 1018,
#        1019, 1020, 1021, 1022, 1025, 1027, 1028, 1030, 1031, 1032, 1033,
#        1034, 1038, 1039, 1040, 1041, 1042, 1045, 1047, 1048, 1049])

# %% [markdown]
# # Initialize and train the models

# %%
import os 
sample_dir = 'generated'
os.makedirs(sample_dir, exist_ok=True)
fixed_latent = torch.randn(100, latent_size, 1, 1,device=device)
sample_random_classes = torch.tensor(np.random.randint(0, n_classes, fixed_latent.shape[0]),device=device)

# %%
import importlib
import modelCspectral as m
importlib.reload(m)

discriminator = m.Discriminator()
discriminator.cuda()
generator = m.Generator(noise_size=100)
generator.cuda()
discriminator_optimizer = torch.optim.Adam(discriminator.parameters(),lr=2e-4,betas=(0.5, 0.999))
#discriminator_optimizer = torch.optim.RMSprop(discriminator.parameters(),lr=1e-5)
#generator_optimizer = torch.optim.RMSprop(generator.parameters(),lr=1e-5)
generator_optimizer = torch.optim.Adam(generator.parameters(),lr=2e-4,betas=(0.5, 0.999))


n_params = dataset_utils.count_trainable_parameters(discriminator);
print(n_params)
n_params = dataset_utils.count_trainable_parameters(generator);
print(n_params)


writer = SummaryWriter()
# Out:
# 32233243
# 16273360

# %%
from dataset_utils import Fit_params, Save_samples_params
with torch.no_grad():
    pass
fit_p = Fit_params(discriminator_optimizer,generator_optimizer,discriminator,generator,dataloaders,device,writer,batch_size,n_classes,latent_size,described_species_labels)
save_p = Save_samples_params(fixed_latent,sample_random_classes,sample_dir)
losses_g, losses_d ,real_scores, fake_scores =m.fit(100,fit_p,save_p,start_idx=1)
# Out:
#   0%|          | 0/204 [00:00<?, ?it/s]
# /home/fogliodicarta/miniconda3/envs/insetti/lib/python3.12/site-packages/torch/nn/modules/module.py:1511: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)
# Epoch [1/100], loss_g: 2.0919, loss_d: 1.4001, real_score: 0.5949, fake_score: 0.4336
# class accuracy real 0.0
# class accuracy fake 0.0
# Saving generated-images-0001.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [2/100], loss_g: 1.4022, loss_d: 1.4437, real_score: 0.5676, fake_score: 0.4159
# class accuracy real 0.046875
# class accuracy fake 0.0
# Saving generated-images-0002.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [3/100], loss_g: 1.6309, loss_d: 1.9761, real_score: 0.4103, fake_score: 0.3907
# class accuracy real 0.015625
# class accuracy fake 0.0
# Saving generated-images-0003.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [4/100], loss_g: 1.4366, loss_d: 1.0351, real_score: 0.7412, fake_score: 0.4314
# class accuracy real 0.015625
# class accuracy fake 0.0
# Saving generated-images-0004.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [5/100], loss_g: 1.3188, loss_d: 1.4933, real_score: 0.5667, fake_score: 0.4545
# class accuracy real 0.0625
# class accuracy fake 0.0
# Saving generated-images-0005.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [6/100], loss_g: 1.9149, loss_d: 1.0061, real_score: 0.6435, fake_score: 0.3267
# class accuracy real 0.015625
# class accuracy fake 0.0
# Saving generated-images-0006.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [7/100], loss_g: 2.1474, loss_d: 0.9853, real_score: 0.5350, fake_score: 0.1570
# class accuracy real 0.078125
# class accuracy fake 0.0
# Saving generated-images-0007.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [8/100], loss_g: 2.8990, loss_d: 0.7834, real_score: 0.7861, fake_score: 0.3666
# class accuracy real 0.03125
# class accuracy fake 0.0
# Saving generated-images-0008.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [9/100], loss_g: 2.6969, loss_d: 0.8313, real_score: 0.7545, fake_score: 0.3912
# class accuracy real 0.0625
# class accuracy fake 0.0
# Saving generated-images-0009.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [10/100], loss_g: 2.1330, loss_d: 1.0237, real_score: 0.8153, fake_score: 0.5064
# class accuracy real 0.015625
# class accuracy fake 0.0
# Saving generated-images-0010.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [11/100], loss_g: 2.7105, loss_d: 0.8170, real_score: 0.7640, fake_score: 0.3642
# class accuracy real 0.046875
# class accuracy fake 0.0
# Saving generated-images-0011.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [12/100], loss_g: 1.1791, loss_d: 0.8122, real_score: 0.6305, fake_score: 0.2347
# class accuracy real 0.03125
# class accuracy fake 0.0
# Saving generated-images-0012.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [13/100], loss_g: 1.9017, loss_d: 0.8140, real_score: 0.6612, fake_score: 0.3035
# class accuracy real 0.109375
# class accuracy fake 0.0
# Saving generated-images-0013.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [14/100], loss_g: 1.9932, loss_d: 0.6111, real_score: 0.6187, fake_score: 0.1238
# class accuracy real 0.078125
# class accuracy fake 0.0
# Saving generated-images-0014.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [15/100], loss_g: 3.7143, loss_d: 1.3554, real_score: 0.8911, fake_score: 0.6456
# class accuracy real 0.078125
# class accuracy fake 0.0
# Saving generated-images-0015.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [16/100], loss_g: 2.0071, loss_d: 0.9906, real_score: 0.6608, fake_score: 0.3473
# class accuracy real 0.03125
# class accuracy fake 0.0
# Saving generated-images-0016.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [17/100], loss_g: 3.1458, loss_d: 0.5370, real_score: 0.9250, fake_score: 0.3752
# class accuracy real 0.078125
# class accuracy fake 0.0
# Saving generated-images-0017.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [18/100], loss_g: 2.2595, loss_d: 0.9851, real_score: 0.6682, fake_score: 0.3801
# class accuracy real 0.0625
# class accuracy fake 0.0
# Saving generated-images-0018.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [19/100], loss_g: 1.9183, loss_d: 0.6595, real_score: 0.5972, fake_score: 0.0977
# class accuracy real 0.0625
# class accuracy fake 0.0
# Saving generated-images-0019.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [20/100], loss_g: 0.7747, loss_d: 1.0661, real_score: 0.4981, fake_score: 0.1983
# class accuracy real 0.078125
# class accuracy fake 0.0
# Saving generated-images-0020.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [21/100], loss_g: 3.7151, loss_d: 0.6814, real_score: 0.8532, fake_score: 0.4011
# class accuracy real 0.109375
# class accuracy fake 0.0
# Saving generated-images-0021.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [22/100], loss_g: 4.1038, loss_d: 1.2500, real_score: 0.8413, fake_score: 0.6130
# class accuracy real 0.109375
# class accuracy fake 0.0
# Saving generated-images-0022.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [23/100], loss_g: 2.1419, loss_d: 0.4314, real_score: 0.6904, fake_score: 0.0955
# class accuracy real 0.125
# class accuracy fake 0.015625
# Saving generated-images-0023.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [24/100], loss_g: 3.1116, loss_d: 0.9775, real_score: 0.7932, fake_score: 0.4688
# class accuracy real 0.09375
# class accuracy fake 0.0
# Saving generated-images-0024.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [25/100], loss_g: 2.5699, loss_d: 0.2875, real_score: 0.8903, fake_score: 0.1933
# class accuracy real 0.078125
# class accuracy fake 0.015625
# Saving generated-images-0025.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [26/100], loss_g: 2.0886, loss_d: 0.2190, real_score: 0.7490, fake_score: 0.1030
# class accuracy real 0.1875
# class accuracy fake 0.0
# Saving generated-images-0026.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [27/100], loss_g: 3.7663, loss_d: 0.4727, real_score: 0.8737, fake_score: 0.2680
# class accuracy real 0.046875
# class accuracy fake 0.015625
# Saving generated-images-0027.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [28/100], loss_g: 3.4495, loss_d: 0.4785, real_score: 0.9656, fake_score: 0.3203
# class accuracy real 0.03125
# class accuracy fake 0.0
# Saving generated-images-0028.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [29/100], loss_g: 2.0216, loss_d: 0.6416, real_score: 0.6605, fake_score: 0.1984
# class accuracy real 0.078125
# class accuracy fake 0.0
# Saving generated-images-0029.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [30/100], loss_g: 1.8465, loss_d: 0.6350, real_score: 0.6512, fake_score: 0.1911
# class accuracy real 0.109375
# class accuracy fake 0.0
# Saving generated-images-0030.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [31/100], loss_g: 4.1142, loss_d: 0.3521, real_score: 0.9162, fake_score: 0.3449
# class accuracy real 0.234375
# class accuracy fake 0.0
# Saving generated-images-0031.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [32/100], loss_g: 3.0004, loss_d: 0.4226, real_score: 0.7667, fake_score: 0.1901
# class accuracy real 0.15625
# class accuracy fake 0.0
# Saving generated-images-0032.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [33/100], loss_g: 2.7106, loss_d: 0.4602, real_score: 0.7099, fake_score: 0.0942
# class accuracy real 0.0625
# class accuracy fake 0.0
# Saving generated-images-0033.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [34/100], loss_g: 2.2180, loss_d: 0.5110, real_score: 0.6271, fake_score: 0.0815
# class accuracy real 0.125
# class accuracy fake 0.0
# Saving generated-images-0034.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [35/100], loss_g: 2.4761, loss_d: 0.2041, real_score: 0.7328, fake_score: 0.0500
# class accuracy real 0.15625
# class accuracy fake 0.0
# Saving generated-images-0035.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [36/100], loss_g: 4.4893, loss_d: 0.3770, real_score: 0.7763, fake_score: 0.1336
# class accuracy real 0.078125
# class accuracy fake 0.0
# Saving generated-images-0036.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [37/100], loss_g: 2.5403, loss_d: 0.4923, real_score: 0.6464, fake_score: 0.0509
# class accuracy real 0.109375
# class accuracy fake 0.0
# Saving generated-images-0037.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [38/100], loss_g: 5.3501, loss_d: 1.1327, real_score: 0.9745, fake_score: 0.6225
# class accuracy real 0.125
# class accuracy fake 0.0
# Saving generated-images-0038.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [39/100], loss_g: 2.9049, loss_d: 0.2558, real_score: 0.7946, fake_score: 0.1297
# class accuracy real 0.15625
# class accuracy fake 0.0
# Saving generated-images-0039.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [40/100], loss_g: 6.8638, loss_d: 1.7539, real_score: 0.9694, fake_score: 0.7521
# class accuracy real 0.109375
# class accuracy fake 0.0
# Saving generated-images-0040.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [41/100], loss_g: 2.7454, loss_d: 0.1461, real_score: 0.8531, fake_score: 0.1764
# class accuracy real 0.203125
# class accuracy fake 0.0
# Saving generated-images-0041.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [42/100], loss_g: 4.3815, loss_d: 0.0815, real_score: 0.8168, fake_score: 0.0318
# class accuracy real 0.15625
# class accuracy fake 0.0
# Saving generated-images-0042.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [43/100], loss_g: 2.0502, loss_d: 0.0499, real_score: 0.9304, fake_score: 0.1263
# class accuracy real 0.125
# class accuracy fake 0.0
# Saving generated-images-0043.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [44/100], loss_g: 3.7750, loss_d: 0.4047, real_score: 0.7608, fake_score: 0.2206
# class accuracy real 0.15625
# class accuracy fake 0.0
# Saving generated-images-0044.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [45/100], loss_g: 3.8539, loss_d: 0.0908, real_score: 0.9305, fake_score: 0.1804
# class accuracy real 0.171875
# class accuracy fake 0.015625
# Saving generated-images-0045.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [46/100], loss_g: 4.0677, loss_d: 0.6635, real_score: 0.9863, fake_score: 0.4496
# class accuracy real 0.109375
# class accuracy fake 0.0
# Saving generated-images-0046.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [47/100], loss_g: 2.0547, loss_d: 0.2702, real_score: 0.7097, fake_score: 0.0773
# class accuracy real 0.1875
# class accuracy fake 0.0
# Saving generated-images-0047.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [48/100], loss_g: 2.9419, loss_d: 0.1352, real_score: 0.8367, fake_score: 0.1161
# class accuracy real 0.171875
# class accuracy fake 0.0
# Saving generated-images-0048.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [49/100], loss_g: 4.5170, loss_d: -0.0613, real_score: 0.9445, fake_score: 0.0731
# class accuracy real 0.1875
# class accuracy fake 0.0
# Saving generated-images-0049.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [50/100], loss_g: 3.5715, loss_d: 0.5812, real_score: 0.6786, fake_score: 0.1979
# class accuracy real 0.1875
# class accuracy fake 0.0
# Saving generated-images-0050.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [51/100], loss_g: 3.9961, loss_d: 0.2544, real_score: 0.9567, fake_score: 0.2912
# class accuracy real 0.15625
# class accuracy fake 0.0
# Saving generated-images-0051.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [52/100], loss_g: 4.3855, loss_d: 0.2290, real_score: 0.7696, fake_score: 0.1109
# class accuracy real 0.15625
# class accuracy fake 0.0
# Saving generated-images-0052.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [53/100], loss_g: 2.4185, loss_d: 0.2574, real_score: 0.8404, fake_score: 0.1284
# class accuracy real 0.09375
# class accuracy fake 0.0
# Saving generated-images-0053.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [54/100], loss_g: 1.4529, loss_d: 0.3825, real_score: 0.6409, fake_score: 0.0172
# class accuracy real 0.140625
# class accuracy fake 0.0
# Saving generated-images-0054.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [55/100], loss_g: 2.1514, loss_d: 0.2302, real_score: 0.7112, fake_score: 0.0324
# class accuracy real 0.15625
# class accuracy fake 0.0
# Saving generated-images-0055.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [56/100], loss_g: 5.7101, loss_d: 0.0724, real_score: 0.8583, fake_score: 0.0125
# class accuracy real 0.109375
# class accuracy fake 0.0
# Saving generated-images-0056.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [57/100], loss_g: 4.3461, loss_d: 0.4428, real_score: 0.9963, fake_score: 0.4585
# class accuracy real 0.234375
# class accuracy fake 0.015625
# Saving generated-images-0057.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [58/100], loss_g: 3.8573, loss_d: 0.0024, real_score: 0.8671, fake_score: 0.0492
# class accuracy real 0.15625
# class accuracy fake 0.0
# Saving generated-images-0058.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [59/100], loss_g: 2.5645, loss_d: 0.0676, real_score: 0.8987, fake_score: 0.0962
# class accuracy real 0.125
# class accuracy fake 0.0
# Saving generated-images-0059.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [60/100], loss_g: 2.3878, loss_d: -0.0185, real_score: 0.8712, fake_score: 0.0505
# class accuracy real 0.203125
# class accuracy fake 0.0
# Saving generated-images-0060.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [61/100], loss_g: 0.7925, loss_d: 0.7071, real_score: 0.5044, fake_score: 0.0455
# class accuracy real 0.125
# class accuracy fake 0.015625
# Saving generated-images-0061.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [62/100], loss_g: 1.5013, loss_d: 0.0838, real_score: 0.7814, fake_score: 0.0306
# class accuracy real 0.171875
# class accuracy fake 0.0
# Saving generated-images-0062.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [63/100], loss_g: 5.0035, loss_d: 0.0444, real_score: 0.9440, fake_score: 0.1125
# class accuracy real 0.125
# class accuracy fake 0.0
# Saving generated-images-0063.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [64/100], loss_g: 3.8466, loss_d: 0.1440, real_score: 0.8174, fake_score: 0.0446
# class accuracy real 0.140625
# class accuracy fake 0.0
# Saving generated-images-0064.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [65/100], loss_g: 2.9130, loss_d: 0.0613, real_score: 0.9713, fake_score: 0.1057
# class accuracy real 0.0625
# class accuracy fake 0.0
# Saving generated-images-0065.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [66/100], loss_g: 4.5271, loss_d: -0.0982, real_score: 0.9514, fake_score: 0.0448
# class accuracy real 0.140625
# class accuracy fake 0.015625
# Saving generated-images-0066.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [67/100], loss_g: 4.9872, loss_d: -0.0678, real_score: 0.9423, fake_score: 0.0658
# class accuracy real 0.1875
# class accuracy fake 0.0
# Saving generated-images-0067.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [68/100], loss_g: 2.2942, loss_d: -0.0116, real_score: 0.9776, fake_score: 0.0491
# class accuracy real 0.078125
# class accuracy fake 0.0
# Saving generated-images-0068.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [69/100], loss_g: 5.4225, loss_d: 0.0958, real_score: 0.7735, fake_score: 0.0190
# class accuracy real 0.203125
# class accuracy fake 0.0
# Saving generated-images-0069.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [70/100], loss_g: 3.0508, loss_d: 0.2926, real_score: 0.9751, fake_score: 0.3638
# class accuracy real 0.234375
# class accuracy fake 0.0
# Saving generated-images-0070.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [71/100], loss_g: 4.6449, loss_d: -0.1379, real_score: 0.9669, fake_score: 0.0704
# class accuracy real 0.1875
# class accuracy fake 0.0
# Saving generated-images-0071.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [72/100], loss_g: 3.2867, loss_d: -0.0292, real_score: 0.9693, fake_score: 0.0864
# class accuracy real 0.140625
# class accuracy fake 0.0
# Saving generated-images-0072.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [73/100], loss_g: 5.2589, loss_d: -0.1355, real_score: 0.9514, fake_score: 0.0498
# class accuracy real 0.203125
# class accuracy fake 0.0
# Saving generated-images-0073.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [74/100], loss_g: 1.1590, loss_d: 0.2201, real_score: 0.7278, fake_score: 0.0252
# class accuracy real 0.171875
# class accuracy fake 0.0
# Saving generated-images-0074.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [75/100], loss_g: 2.3263, loss_d: 0.5740, real_score: 0.5719, fake_score: 0.0408
# class accuracy real 0.125
# class accuracy fake 0.0
# Saving generated-images-0075.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [76/100], loss_g: 3.3877, loss_d: 0.1013, real_score: 0.7818, fake_score: 0.0386
# class accuracy real 0.171875
# class accuracy fake 0.0
# Saving generated-images-0076.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [77/100], loss_g: 2.5482, loss_d: 0.3254, real_score: 0.6664, fake_score: 0.0806
# class accuracy real 0.21875
# class accuracy fake 0.0
# Saving generated-images-0077.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [78/100], loss_g: 8.9402, loss_d: 1.7242, real_score: 0.9975, fake_score: 0.7752
# class accuracy real 0.21875
# class accuracy fake 0.0
# Saving generated-images-0078.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [79/100], loss_g: 2.2216, loss_d: 0.8326, real_score: 0.6205, fake_score: 0.2001
# class accuracy real 0.0625
# class accuracy fake 0.0
# Saving generated-images-0079.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# Epoch [80/100], loss_g: 4.9738, loss_d: 0.3402, real_score: 0.9553, fake_score: 0.2934
# class accuracy real 0.125
# class accuracy fake 0.0
# Saving generated-images-0080.png
#   0%|          | 0/204 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 6
#       4 fit_p = Fit_params(discriminator_optimizer,generator_optimizer,discriminator,generator,dataloaders,device,writer,batch_size,n_classes,latent_size,described_species_labels)
#       5 save_p = Save_samples_params(fixed_latent,sample_random_classes,sample_dir)
# ----> 6 losses_g, losses_d ,real_scores, fake_scores =m.fit(100,fit_p,save_p,start_idx=1)
#
# File ~/Desktop/InsectClassification/modelCspectral.py:223, in fit(epochs, fit_p, save_p, start_idx, latent_size)
#     219 fake_scores = []
#     222 for epoch in range(epochs):
# --> 223     for real_images, real_classes in tqdm(fit_p.dataloaders['train']):
#     224         # Train discriminator
#     225         real_images = real_images.to(fit_p.device)
#     226         real_classes = real_classes.to(fit_p.device)
#
# File ~/miniconda3/envs/insetti/lib/python3.12/site-packages/tqdm/notebook.py:254, in tqdm_notebook.__iter__(self)
#     252 try:
#     253     it = super(tqdm_notebook, self).__iter__()
# --> 254     for obj in it:
#     255         # return super(tqdm...) will not catch exception
#     256         yield obj
#     257 # NB: except ... [ as ...] breaks IPython async KeyboardInterrupt
#
# File ~/miniconda3/envs/insetti/lib/python3.12/site-packages/tqdm/std.py:1178, in tqdm.__iter__(self)
#    1175 time = self._time
#    1177 try:
# -> 1178     for obj in iterable:
#    1179         yield obj
#    1180         # Update and possibly print the progressbar.
#    1181         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/miniconda3/envs/insetti/lib/python3.12/site-packages/torch/utils/data/dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/miniconda3/envs/insetti/lib/python3.12/site-packages/torch/utils/data/dataloader.py:1329, in _MultiProcessingDataLoaderIter._next_data(self)
#    1326     return self._process_data(data)
#    1328 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1329 idx, data = self._get_data()
#    1330 self._tasks_outstanding -= 1
#    1331 if self._dataset_kind == _DatasetKind.Iterable:
#    1332     # Check for _IterableDatasetStopIteration
#
# File ~/miniconda3/envs/insetti/lib/python3.12/site-packages/torch/utils/data/dataloader.py:1295, in _MultiProcessingDataLoaderIter._get_data(self)
#    1291     # In this case, `self._data_queue` is a `queue.Queue`,. But we don't
#    1292     # need to call `.task_done()` because we don't use `.join()`.
#    1293 else:
#    1294     while True:
# -> 1295         success, data = self._try_get_data()
#    1296         if success:
#    1297             return data
#
# File ~/miniconda3/envs/insetti/lib/python3.12/site-packages/torch/utils/data/dataloader.py:1133, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1120 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#    1121     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1122     # This can also be used as inner loop of fetching without timeout, with
#    (...)
#    1130     # Returns a 2-tuple:
#    1131     #   (bool: whether successfully get data, any: data if successful else None)
#    1132     try:
# -> 1133         data = self._data_queue.get(timeout=timeout)
#    1134         return (True, data)
#    1135     except Exception as e:
#    1136         # At timeout and error, we manually check whether any worker has
#    1137         # failed. Note that this is the only mechanism for Windows to detect
#    1138         # worker failures.
#
# File ~/miniconda3/envs/insetti/lib/python3.12/multiprocessing/queues.py:113, in Queue.get(self, block, timeout)
#     111 if block:
#     112     timeout = deadline - time.monotonic()
# --> 113     if not self._poll(timeout):
#     114         raise Empty
#     115 elif not self._poll():
#
# File ~/miniconda3/envs/insetti/lib/python3.12/multiprocessing/connection.py:257, in _ConnectionBase.poll(self, timeout)
#     255 self._check_closed()
#     256 self._check_readable()
# --> 257 return self._poll(timeout)
#
# File ~/miniconda3/envs/insetti/lib/python3.12/multiprocessing/connection.py:440, in Connection._poll(self, timeout)
#     439 def _poll(self, timeout):
# --> 440     r = wait([self], timeout)
#     441     return bool(r)
#
# File ~/miniconda3/envs/insetti/lib/python3.12/multiprocessing/connection.py:1135, in wait(object_list, timeout)
#    1132     deadline = time.monotonic() + timeout
#    1134 while True:
# -> 1135     ready = selector.select(timeout)
#    1136     if ready:
#    1137         return [key.fileobj for (key, events) in ready]
#
# File ~/miniconda3/envs/insetti/lib/python3.12/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:

# %%
dataset_utils.species_label_to_genus_label()

# %% [markdown]
# # Altra roba

# %%
torch.save({
            'epoch':100,
            'model_state_dict': generator.state_dict(),
            'optimizer_state_dict': generator_optimizer.state_dict(),
            }, "checkpoints/generatorCSpectralNormEmbedding1000EMBEDDINGNORM")
torch.save({
            'epoch': 100,
            'model_state_dict': discriminator.state_dict(),
            'optimizer_state_dict': discriminator_optimizer.state_dict(),
            }, "checkpoints/discriminatorCSpectralNormEmbedding1000EMBEDDINGNORM")

# %% [markdown]
# # Random forest benchmark, da cancellare

# %%
def extract_features(self,x):
    x = self.main(x)
    x = self.flatten(x)
    return x
m.Discriminator.extract_features = extract_features

discriminator = m.Discriminator()
discriminator.cuda()
generator = m.Generator(noise_size=100)
generator.cuda()
# Out:
# Generator(
#   (embed): Embedding(1050, 200)
#   (main): Sequential(
#     (0): Tpose(
#       (main): Sequential(
#         (0): ConvTranspose2d(300, 1024, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#     )
#     (1): Tpose(
#       (main): Sequential(
#         (0): ConvTranspose2d(1024, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#     )
#     (2): Tpose(
#       (main): Sequential(
#         (0): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#     )
#     (3): Tpose(
#       (main): Sequential(
#         (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#     )
#     (4): Tpose(
#       (main): Sequential(
#         (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#     )
#     (5): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (6): Tanh()
#   )
# )

# %%
suffix = "CSpectralNormEmbedding200"
g_dict = torch.load('checkpoints/generator'+suffix)
generator.load_state_dict(g_dict['model_state_dict'])
d_dict = torch.load('checkpoints/discriminator'+suffix)
discriminator.load_state_dict(d_dict['model_state_dict'])
generator_optimizer.load_state_dict(g_dict['optimizer_state_dict'])
discriminator_optimizer.load_state_dict(d_dict['optimizer_state_dict'])

# %%
df = pd.read_csv('final_dataset.csv',index_col=0)
tform = transforms.Compose([transforms.Resize((64,64)),transforms.PILToTensor(),transforms.ConvertImageDtype(torch.float),transforms.Normalize(0.5,0.5)])
image_dataset = torchvision.datasets.ImageFolder("image_dataset/",transform=tform)

# %%
batch_size = 1000 
import random
import dataset_utils
img2dna = dataset_utils.get_imgs_bold_id(image_dataset,df)

nucleotides = df[['nucleotide','species_name','genus_name','processid','image_urls']]
colonna_dna = df.loc[:,"nucleotide"]
nucleotides.loc[:,'nucleotide'] = colonna_dna.apply(dataset_utils.one_hot_encoding)
random.seed(42)

X_train_1, X_test, y_train_1, y_test = dataset_utils.data_split(nucleotides,0.2,random_state=42)
print(y_test)
train_data = X_train_1
train_data['species_name'] = y_train_1

X_train, X_validation, y_train, y_validation = dataset_utils.data_split(train_data,0.2,drop_labels=False,random_state=42)
train_indices, val_indices, test_indices = dataset_utils.image_splits_from_df(X_train,X_validation,X_test,image_dataset)
from torch.utils.data import Dataset, DataLoader
 
class WholeDataset(Dataset):
    def __init__(self, data, transform=None):
        self.data = data
        self.targets = data.targets#torch.tensor(targets)
        #self.transform = transform
        
    def __getitem__(self, index):
        x = self.data[index][0]
        y = self.targets[index]
        
        return x, y
    
    def __len__(self):
        return len(self.data)
        
whole_dataset = WholeDataset(image_dataset)
n_classes = np.unique(whole_dataset.targets).shape[0]
print(len(test_indices+val_indices+train_indices))
len(whole_dataset)

train_imgs = torch.utils.data.Subset(whole_dataset, train_indices)
val_imgs = torch.utils.data.Subset(whole_dataset, val_indices)
test_imgs = torch.utils.data.Subset(whole_dataset, test_indices)
len(train_imgs)+len(val_imgs)+len(test_imgs)
train_loader = torch.utils.data.DataLoader(train_imgs, batch_size=batch_size,shuffle=False, num_workers=2)
val_loader = torch.utils.data.DataLoader(val_imgs, batch_size=2000,shuffle=False, num_workers=2)
test_loader = torch.utils.data.DataLoader(test_imgs, batch_size=4,shuffle=False, num_workers=2)
#del test_loader
dataloaders = {"train":train_loader,"val":val_loader}
dataset_sizes = {'train': len(train_imgs.indices), 'val':len(val_imgs.indices)}

described_species_labels = np.array([image_dataset.targets[i] for i in train_indices])
described_species_labels = np.unique(described_species_labels)


species2genus = dataset_utils.species_label_to_genus_label(df,image_dataset)
# Out:
# 365    Bembidion normannum
# 292       Bledius gallicus
# 321       Praxis edwardsii
# 352        Andrena pilipes
# 18     Automeris managuana
#               ...
# 412         Hemiceras losa
# 413         Hemiceras losa
# 417     Hemiceras punctata
# 418         Hemiceras losa
# 421     Hemiceras punctata
# Name: species_name, Length: 9991, dtype: object
# 32424

# %%
train_features = []
train_labels = np.array([]) 
with torch.no_grad():
    for batch, targets in dataloaders['train']:
        features_torch = discriminator.extract_features(batch.cuda()) 
        features_targets_torch = targets
        train_labels = np.concatenate((train_labels, features_targets_torch.cpu().numpy()))
        train_features.append(features_torch.cpu().numpy())
        torch.cuda.empty_cache()

train_features = np.concatenate(train_features)

# %%
torch.cuda.empty_cache()
discriminator.eval()
val_features = []
val_labels = np.array([])
with torch.no_grad():
    for batch,targets in dataloaders['val']:
        features_torch = discriminator.extract_features(batch.cuda()) 
        features_targets_torch = targets
        val_labels = np.concatenate((val_labels, features_targets_torch.cpu().numpy()))
        val_features.append(features_torch.cpu().numpy())
        torch.cuda.empty_cache()

val_features = np.concatenate(val_features)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier 
#svm = LinearSVC(random_state=42)

# Make it an Multilabel classifier
#multilabel_classifier = MultiOutputClassifier(svm, n_jobs=-1)

# Fit the data to the Multilabel classifier
#svm = svm.fit(train_features, train_labels)

# Get predictions for test data
#y_test_pred = svm.predict(train_features)
clf = RandomForestClassifier(min_samples_leaf=2,n_jobs=-1)
clf = clf.fit(train_features, train_labels)

# %%
train_predicted_labels = clf.predict(train_features)
print(f"Training species accuracy:{np.count_nonzero(train_predicted_labels==train_labels)/len(train_labels)}")
val_predicted_labels= clf.predict(val_features)
print(f"Validation species accuracy:{np.count_nonzero(val_predicted_labels==val_labels)/len(val_labels)}")
temp_val_predicted_probs = clf.predict_proba(val_features)
val_predicted_probs = np.zeros((len(temp_val_predicted_probs),n_classes))
for i, cls in enumerate(np.arange(n_classes)):
    if cls in clf.classes_:
        val_predicted_probs[:, cls] = temp_val_predicted_probs[:, list(clf.classes_).index(cls)]
#i = 100
import math
n_correct_genus = 0
for i in range(len(val_labels)):
    #label_best_specie = val_predicted_probs[i].argmax()
    label_best_specie = val_predicted_labels[i]
    
    #assert(int(val_predicted_labels[i])==int(val_predicted_probs[i].argmax()))
    genus_of_best_species = species2genus[label_best_specie.item()]
    #species_same_genus = [k for k,v in species2genus.items() if v == genus_of_best_species]
    #reduced_species = val_predicted_probs[i][species_same_genus]
    #normalized_reduced_species = reduced_species/(reduced_species.sum())
    
    real_genus = species2genus[val_labels[i]]
    predicted_genus = genus_of_best_species
    if real_genus == predicted_genus:
        n_correct_genus+=1
print(f"Validation genus accuracy: {n_correct_genus/len(val_labels)}")
