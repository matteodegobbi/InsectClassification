# %%
boldid
# Out:
# ['ASALC391-13',
#  'UAMIC208-13',
#  'ERPIR009-12',
#  'COLFF963-13',
#  'NOCLP1545-19',
#  'COLFA474-12',
#  'COLFE461-12',
#  'FBCOC917-10',
#  'COLFD039-12',
#  'COLFB157-12',
#  'COLFB765-12',
#  'COLFC655-12',
#  'COLFE1498-13',
#  'COLFF868-13',
#  'ASALC392-13',
#  'BBCCA2216-12',
#  'BBCCA2218-12',
#  'BBCCA2215-12',
#  'BBCCA2217-12',
#  'GMGLD010-13',
#  'GMGLF065-13',
#  'GMGLG1117-13',
#  'UAMIC206-13',
#  'UAMIC336-13',
#  'COLFA481-12',
#  'COLFB137-12',
#  'COLFB611-12',
#  'COLFD646-12',
#  'COLFD262-12',
#  'COLFA615-12',
#  'COLFD685-12',
#  'COLFB032-12',
#  'COLFD686-12',
#  'COLFE438-12',
#  'COLFB053-12',
#  'COLFB323-12',
#  'COLFB324-12',
#  'COLFD201-12',
#  'COLFD202-12',
#  'COLFC585-12',
#  'FBCOE470-12',
#  'COLFD681-12',
#  'FBCOA412-10',
#  'FBCOD310-11',
#  'COLFD044-12',
#  'COLFE532-13',
#  'FBCOC654-10',
#  'COLFE745-13',
#  'FBCOG1098-12',
#  'COLFE363-12',
#  'COLFE604-13',
#  'FBCOC452-10',
#  'FBCOF1123-12',
#  'FBCOF1081-12',
# ...

# %%
# Out:
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# 659
# ...

# %%
# Out:
# array([[615]], dtype=uint16)
